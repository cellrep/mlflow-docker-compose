# %%
from mlflow.server import get_app_client

# %%
auth_client = get_app_client("basic-auth", tracking_uri='http://ai.cellrep.bio:5000')

# %%
auth_client.update_user_password(
    "admin", "pass"
)

# %%
auth_client.create_user(username="admin", password="pass")
auth_client.update_user_admin(username="usuario", is_admin=True)
# Out:
# ---------------------------------------------------------------------------
# RestException                             Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 auth_client.create_user(username="admin", password="c311#rep!")
#       2 auth_client.update_user_admin(username="usuario", is_admin=True)
#
# File ~/miniconda3/envs/cellrep-screening/lib/python3.12/site-packages/mlflow/server/auth/client.py:74, in AuthServiceClient.create_user(self, username, password)
#      40 def create_user(self, username: str, password: str):
#      41     """
#      42     Create a new user.
#      43
#    (...)
#      72         is_admin: False
#      73     """
# ---> 74     resp = self._request(
#      75         CREATE_USER,
#      76         "POST",
#      77         json={"username": username, "password": password},
#      78     )
#      79     return User.from_json(resp["user"])
#
# ...
